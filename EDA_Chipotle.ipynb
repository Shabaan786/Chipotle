# %% [markdown]
# <a href="https://colab.research.google.com/github/Shabaan786/Chipotle/blob/main/EDA_Chipotle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/Shabaan786/Chipotle/main/Chipotle.csv"
Ada = pd.read_csv(url)

# %%
Ada.head(10)
# Out:
#           top1 wordofmouth socialmedia walkby billboard  patronage  \
# 0    Applebees         Yes          No     No        No          0
# 1        Arbys         Yes          No     No        No          0
# 2        Arbys          No          No    Yes        No          0
# 3        Arbys          No          No     No        No          0
# 4  Burger King          No         Yes     No        No          0
# 5  Chick-Fil-A         Yes          No     No        No          0
# 6  Chick-Fil-A          No          No    Yes        No          0
# 7  Chick-Fil-A          No          No    Yes        No          0
# 8  Chick-Fil-A          No          No    Yes        No          1
# 9  Chick-Fil-A         Yes          No     No        No          0
#
#    importantconvenience  importantvariety  importantprice  importanthealthy  \
# 0                   4.0               4.0             5.0               4.0
# ...

# %%
Ada.describe()
# Out:
#         patronage  importantconvenience  importantvariety  importantprice  \
# count  357.000000            338.000000        333.000000      334.000000
# mean     0.487395              4.500000          4.312312        4.670659
# std      1.128280              0.659332          0.688808        0.589631
# min      0.000000              1.000000          1.000000        2.000000
# 25%      0.000000              4.000000          4.000000        4.000000
# 50%      0.000000              5.000000          4.000000        5.000000
# 75%      0.000000              5.000000          5.000000        5.000000
# max      6.000000              5.000000          5.000000        5.000000
#
#        importanthealthy  importanttaste  importantambience  \
# count        335.000000      332.000000         335.000000
# mean           4.534328        4.927711           4.232836
# std            0.668709        0.259357           0.660790
# min            2.000000        4.000000           1.000000
# ...

# %%
Ada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   top1                  357 non-null    object
#  1   wordofmouth           357 non-null    object
#  2   socialmedia           357 non-null    object
#  3   walkby                357 non-null    object
#  4   billboard             357 non-null    object
#  5   patronage             357 non-null    int64
#  6   importantconvenience  338 non-null    float64
#  7   importantvariety      333 non-null    float64
#  8   importantprice        334 non-null    float64
#  9   importanthealthy      335 non-null    float64
#  10  importanttaste        332 non-null    float64
#  11  importantambience     335 non-null    float64
#  12  chipotleconvenient    334 non-null    float64
#  13  chipotlevariety       333 non-null    float64
# ...

# %%
Ada['gender'].value_counts()
# Out:
# Male      271
# Female     72
# Name: gender, dtype: int64

# %%
Ada['top1'].value_counts()
# Out:
# In-n-out         76
# El Pollo Loco    57
# Panera           50
# Chipotle         42
# Subway           40
# Chick-Fil-A      33
# KFC              25
# McDonalds        17
# Arbys             3
# Starbucks         2
# Wendy's           2
# Jasons Deli       2
# Outback           1
# Pizza express     1
# Pizza Hut         1
# Eppies            1
# Burger King       1
# Taco Bell         1
# The Market        1
# Applebees         1
# Name: top1, dtype: int64

# %%
Ada.corr()
# Out:
#                       patronage  importantconvenience  importantvariety  \
# patronage              1.000000             -0.184009         -0.089479
# importantconvenience  -0.184009              1.000000          0.379041
# importantvariety      -0.089479              0.379041          1.000000
# importantprice        -0.031176              0.219773          0.358237
# importanthealthy      -0.194962              0.177598          0.331164
# importanttaste        -0.020958              0.022364          0.093630
# importantambience     -0.186999              0.191377          0.375228
# chipotleconvenient    -0.142545              0.192236          0.096802
# chipotlevariety       -0.015089              0.093584          0.360278
# chipotleprice         -0.015940              0.128264          0.282238
# chipotlehealthy       -0.078458              0.137211          0.131349
# chipotletaste         -0.054768              0.143569          0.103151
# ...

# %%
sns.heatmap(Ada.corr(), annot=True)

# %%
sns.heatmap(Ada.corr(), cmap="YlGnBu")

# %%
importance = Ada.iloc[:,7:12]

# %%
sns.pairplot(Ada)

# %%
sns.scatterplot(x="age", y="gender", data=Ada)

# %%
sns.lmplot(x = "age", y = "income", data = Ada)

# %%
sns.scatterplot(x="age", y="income", hue="gender", data=Ada)

# %%
sns.lmplot(x = "age", y = "income", hue="gender", data = Ada)

# %%
sns.countplot(x='age', data=Ada)

# %%
sns.countplot(x='income', data=Ada, color='orange')

# %%
Ada_day=Ada.groupby("age")
Ada_day.mean()
# Out:
#       patronage  importantconvenience  importantvariety  importantprice  \
# age
# 18.0   0.000000              4.800000          5.000000        4.800000
# 19.0   1.750000              4.833333          4.500000        4.833333
# 20.0   0.666667              5.000000          3.500000        4.500000
# 21.0   1.000000              4.666667          4.000000        4.666667
# 22.0   1.714286              5.000000          4.666667        5.000000
# 23.0   0.666667              5.000000          5.000000        5.000000
# 24.0   0.400000              4.400000          3.800000        4.600000
# 25.0   0.000000              4.500000          4.500000        5.000000
# 28.0   0.000000              4.666667          3.000000        3.333333
# 29.0   0.105263              4.684211          4.684211        4.947368
# 30.0   0.000000              5.000000          3.200000        5.000000
# 31.0   0.571429              4.285714          4.285714        5.000000
# ...

# %%
sns.boxplot(x="age", y="gender", data=Ada)

# %%
sns.boxplot(x="age", y="income", hue="gender", data=Ada)

# %%
Ada_top3_Ada = Ada.nlargest(3, "age")
Ada_top3_Ada
# Out:
#               top1 wordofmouth socialmedia walkby billboard  patronage  \
# 166       In-n-out         Yes          No     No        No          0
# 116  El Pollo Loco          No         Yes     No        No          0
# 27     Chick-Fil-A         Yes          No     No        No          0
#
#      importantconvenience  importantvariety  importantprice  importanthealthy  \
# 166                   5.0               NaN             5.0               NaN
# 116                   4.0               4.0             5.0               5.0
# 27                    5.0               4.0             4.0               3.0
#
#      ...  chipotlehealthy  chipotletaste  chipotleambience  gender   age  \
# 166  ...              3.0            5.0               5.0  Female  77.0
# 116  ...              5.0            5.0               5.0    Male  73.0
# 27   ...              4.0            4.0               3.0    Male  69.0
#
#       income  plan  spending buylocal  healthyimportanttome
# ...
